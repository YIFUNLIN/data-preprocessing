# %%
# !pip install wget
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9680 sha256=074ed80eb16554508bdfeae89d0ec9a5a75f1e822006600adedd31101d5f1ba2
#   Stored in directory: c:\users\linnn\appdata\local\pip\cache\wheels\bd\a8\c3\3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...

# %%
import pandas as pd
import wget

# %%
wget.download('https://raw.githubusercontent.com/PaulCrickard/escooter/master/scooter.csv')
# Out:
# 100% [..........................................................................] 6011006 / 6011006
# 'scooter.csv'

# %%
df = pd.read_csv('scooter.csv')

# %%
df
# Out:
#       month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0       May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1       May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2       May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3       May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 4       May  1636714        202     8926493  5/24/2019 13:38  5/24/2019 13:41
# ...     ...      ...        ...         ...              ...              ...
# 34221  July  2482235        202     2893981  7/21/2019 23:51   7/22/2019 0:05
# 34222  July  2482254        202     8201542  7/21/2019 23:52   7/22/2019 0:00
# 34223  July  2482257        202     5136810  7/21/2019 23:52   7/22/2019 1:45
# 34224  July  2482275        202     3125962  7/21/2019 23:53   7/22/2019 0:05
# 34225  July  2482335        202     9449822  7/21/2019 23:55   7/22/2019 1:46
#
# ...

# %%
df.columns        #查看所有欄位
# Out:
# Index(['month', 'trip_id', 'region_id', 'vehicle_id', 'started_at', 'ended_at',
#        'DURATION', 'start_location_name', 'end_location_name', 'user_id',
#        'trip_ledger_id'],
#       dtype='object')

# %%
len(df.columns)        #看所有欄位的數量
# Out:
# 11

# %%
df.dtypes    #查看所有欄位型態
# Out:
# month                  object
# trip_id                 int64
# region_id               int64
# vehicle_id              int64
# started_at             object
# ended_at               object
# DURATION               object
# start_location_name    object
# end_location_name      object
# user_id                 int64
# trip_ledger_id          int64
# dtype: object

# %%
df.head()   #可察看前_筆資料，預設為5
# Out:
#   month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0   May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1   May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2   May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3   May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 4   May  1636714        202     8926493  5/24/2019 13:38  5/24/2019 13:41
#
#   DURATION                                start_location_name  \
# 0  0:07:03       1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1  0:04:57  1 Domenici Center en Domenici Center, Albuquer...
# 2  0:01:14  1 Domenici Center en Domenici Center, Albuquer...
# 3  0:06:58  Rotunda at Science & Technology Park, 801 Univ...
# 4  0:03:06          401 2nd St NW, Albuquerque, NM 87102, USA
#
#                                    end_location_name   user_id  trip_ledger_id
# ...

# %%
df.tail()    #查看從最後數來_筆的資料
# Out:
#       month  trip_id  region_id  vehicle_id       started_at        ended_at  \
# 34221  July  2482235        202     2893981  7/21/2019 23:51  7/22/2019 0:05
# 34222  July  2482254        202     8201542  7/21/2019 23:52  7/22/2019 0:00
# 34223  July  2482257        202     5136810  7/21/2019 23:52  7/22/2019 1:45
# 34224  July  2482275        202     3125962  7/21/2019 23:53  7/22/2019 0:05
# 34225  July  2482335        202     9449822  7/21/2019 23:55  7/22/2019 1:46
#
#       DURATION                               start_location_name  \
# 34221  0:14:00    Central @ Broadway, Albuquerque, NM 87102, USA
# 34222  0:08:00    224 Central Ave SW, Albuquerque, NM 87102, USA
# 34223  1:53:00    105 Stanford Dr SE, Albuquerque, NM 87106, USA
# 34224  0:12:00  100 Broadway Blvd SE, Albuquerque, NM 87102, USA
# 34225  1:51:00    105 Stanford Dr SE, Albuquerque, NM 87106, USA
#
#                                       end_location_name   user_id  \
# ...

# %%
len(df)    #看資料總數
# Out:
# 34226

# %%
print(pd.options.display.max_rows)      #系統預設最多只會顯示60列資料
print(pd.options.display.max_columns)   #系統預設最多顯示60欄位
# Out:
# 60
# 20

# %%
pd.set_option('display.max_columns',20)  #更改顯示的預設欄位數值

# %%
print(pd.options.display.max_columns)
# Out:
# 20

# %%
df.head()   #只顯示20個欄位
# Out:
#   month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0   May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1   May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2   May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3   May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 4   May  1636714        202     8926493  5/24/2019 13:38  5/24/2019 13:41
#
#   DURATION                                start_location_name  \
# 0  0:07:03       1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1  0:04:57  1 Domenici Center en Domenici Center, Albuquer...
# 2  0:01:14  1 Domenici Center en Domenici Center, Albuquer...
# 3  0:06:58  Rotunda at Science & Technology Park, 801 Univ...
#
:06:58  Rotunda at Science & Technology Park, 801 Univ...
# 4  0:03:06          401 2nd St NW, Albuquerque, NM 87102, USA
# 5  0:21:27     520 Central Ave SW, Albuquerque, NM 87102, USA
# 6  0:30:43     330 Tijeras Ave NW, Albuquerque, NM 87102, USA
# 7  0:01:05   3217 Pershing Ave SE, Albuquerque, NM 87106, USA
# 8  0:05:33      809 Copper Ave NW, Albuquerque, NM 87102, USA
#
# ...

# %%
df.loc[34221]    #指定印出某筆資料
# Out:
# month                                                            July
# trip_id                                                       2482235
# region_id                                                         202
# vehicle_id                                                    2893981
# started_at                                            7/21/2019 23:51
# ended_at                                               7/22/2019 0:05
# DURATION                                                      0:14:00
# start_location_name    Central @ Broadway, Albuquerque, NM 87102, USA
# end_location_name          1418 4th St NW, Albuquerque, NM 87102, USA
# user_id                                                      42559731
# trip_ledger_id                                                2340035
# Name: 34221, dtype: object

# %%
df.at[34221,'DURATION']    #指定印出某位置、欄位的值
# Out:
# '0:14:00'

# %%
df.where(df['user_id']==8417864)   #用df.where  也會把非符合的資料呈現出來
# Out:
#       month    trip_id  region_id  vehicle_id       started_at  \
# 0       May  1613335.0      202.0   9424537.0  5/21/2019 18:33
# 1       May  1613639.0      202.0   9424537.0  5/21/2019 19:07
# 2       May  1613708.0      202.0   9424537.0  5/21/2019 19:13
# 3       May  1613867.0      202.0   9424537.0  5/21/2019 19:29
# 4       NaN        NaN        NaN         NaN              NaN
# ...     ...        ...        ...         ...              ...
# 34221   NaN        NaN        NaN         NaN              NaN
# 34222   NaN        NaN        NaN         NaN              NaN
# 34223   NaN        NaN        NaN         NaN              NaN
# 34224   NaN        NaN        NaN         NaN              NaN
# 34225   NaN        NaN        NaN         NaN              NaN
#
#               ended_at DURATION  \
# 0      5/21/2019 18:40  0:07:03
# 1      5/21/2019 19:12  0:04:57
# 2      5/21/2019 19:15  0:01:14
# 3      5/21/2019 19:36  0:06:58
# 4                  NaN      NaN
# ...

# %%
df['user_id']==8417864    #會傳boolean值，看是否符合條件
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 34221    False
# 34222    False
# 34223    False
# 34224    False
# 34225    False
# Name: user_id, Length: 34226, dtype: bool

# %%
df[(df['user_id']==8417864)]     #從boolean value中查看符合條件的資料，挑出那列所有的資料作呈現
# Out:
#      month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 0      May  1613335        202     9424537  5/21/2019 18:33  5/21/2019 18:40
# 1      May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
# 2      May  1613708        202     9424537  5/21/2019 19:13  5/21/2019 19:15
# 3      May  1613867        202     9424537  5/21/2019 19:29  5/21/2019 19:36
# 1256   May  1681624        202     8192169   5/27/2019 1:11   5/27/2019 1:11
#
#      DURATION                                start_location_name  \
# 0     0:07:03       1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1     0:04:57  1 Domenici Center en Domenici Center, Albuquer...
# 2     0:01:14  1 Domenici Center en Domenici Center, Albuquer...
# 3     0:06:58  Rotunda at Science & Technology Park, 801 Univ...
# 1256  0:00:12    2513 Comanche Rd NE, Albuquerque, NM 87107, USA
#
#                                       end_location_name  user_id  \
# ...

# %%
#設定兩種條件去篩選資料
one = df['user_id'] ==8417864
two = df['trip_ledger_id'] == 1488838

# %%
df.where(one & two)   #只有一筆資料符合條件，但還是全部都回傳出來
# Out:
#       month    trip_id  region_id  vehicle_id       started_at  \
# 0       NaN        NaN        NaN         NaN              NaN
# 1       May  1613639.0      202.0   9424537.0  5/21/2019 19:07
# 2       NaN        NaN        NaN         NaN              NaN
# 3       NaN        NaN        NaN         NaN              NaN
# 4       NaN        NaN        NaN         NaN              NaN
# ...     ...        ...        ...         ...              ...
# 34221   NaN        NaN        NaN         NaN              NaN
# 34222   NaN        NaN        NaN         NaN              NaN
# 34223   NaN        NaN        NaN         NaN              NaN
# 34224   NaN        NaN        NaN         NaN              NaN
# 34225   NaN        NaN        NaN         NaN              NaN
#
#               ended_at DURATION  \
# 0                  NaN      NaN
# 1      5/21/2019 19:12  0:04:57
# 2                  NaN      NaN
# 3                  NaN      NaN
# 4                  NaN      NaN
# ...

# %%
df[(one & two)]      #只印出符合條件的那列資料
# Out:
#   month  trip_id  region_id  vehicle_id       started_at         ended_at  \
# 1   May  1613639        202     9424537  5/21/2019 19:07  5/21/2019 19:12
#
#   DURATION                                start_location_name  \
# 1  0:04:57  1 Domenici Center en Domenici Center, Albuquer...
#
#                                  end_location_name  user_id  trip_ledger_id
# 1  1111 Stanford Dr NE, Albuquerque, NM 87106, USA  8417864         1488838

# %%
df.describe()
# Out:
#             trip_id  region_id    vehicle_id       user_id  trip_ledger_id
# count  3.422600e+04    34226.0  3.422600e+04  3.422600e+04    3.422600e+04
# mean   2.004438e+06      202.0  5.589507e+06  3.875420e+07    1.869549e+06
# std    2.300476e+05        0.0  2.627164e+06  4.275441e+06    2.252639e+05
# min    1.613335e+06      202.0  1.034847e+06  1.080200e+04    1.488546e+06
# 25%    1.813521e+06      202.0  3.260435e+06  3.665710e+07    1.683023e+06
# 50%    1.962520e+06      202.0  5.617097e+06  3.880750e+07    1.827796e+06
# 75%    2.182324e+06      202.0  8.012871e+06  4.222774e+07    2.042524e+06
# max    2.482335e+06      202.0  9.984848e+06  4.258732e+07    2.342161e+06

# %%
df['start_location_name'].head(2)
# Out:
# 0         1901 Roma Ave NE, Albuquerque, NM 87106, USA
# 1    1 Domenici Center en Domenici Center, Albuquer...
# Name: start_location_name, dtype: object

# %%
df['start_location_name'].describe()   #對單一欄位做描述
# Out:
# count                                               34220
# unique                                               2972
# top       1898 Mountain Rd NW, Albuquerque, NM 87104, USA
# freq                                                 1210
# Name: start_location_name, dtype: object

# %%
df['DURATION'].value_counts()    #對相同的欄位內資料做次數累加
# Out:
# 0:04:00    825
# 0:03:00    807
# 0:05:00    728
# 0:06:00    649
# 0:07:00    627
#           ...
# 1:13:59      1
# 0:57:15      1
# 0:48:03      1
# 1:21:42      1
# 4:43:00      1
# Name: DURATION, Length: 4135, dtype: int64

# %%
df['DURATION'].value_counts(normalize=True)    #將欄位內重複的資料用百分比呈現
# Out:
# 0:04:00    0.025847
# 0:03:00    0.025284
# 0:05:00    0.022808
# 0:06:00    0.020333
# 0:07:00    0.019644
#              ...
# 1:13:59    0.000031
# 0:57:15    0.000031
# 0:48:03    0.000031
# 1:21:42    0.000031
# 4:43:00    0.000031
# Name: DURATION, Length: 4135, dtype: float64

# %%
df['end_location_name'].value_counts(dropna = False)      #印出該欄位內資料的累加，保留NAN值
# Out:
# NaN                                                2070
# 1898 Mountain Rd NW, Albuquerque, NM 87104, USA     802
# Central @ Tingley, Albuquerque, NM 87104, USA       622
# 330 Tijeras Ave NW, Albuquerque, NM 87102, USA      529
# 2550 Central Ave NE, Albuquerque, NM 87106, USA     478
#                                                    ...
# 122 Girard Blvd SE, Albuquerque, NM 87106, USA        1
# 407 Harvard Dr SE, Albuquerque, NM 87106, USA         1
# 2315 Lead Ave SE, Albuquerque, NM 87106, USA          1
# 509 Iron Ave SW, Albuquerque, NM 87102, USA           1
# 1417 Lomas Blvd NW, Albuquerque, NM 87104, USA        1
# Name: end_location_name, Length: 4264, dtype: int64

# %%
df['end_location_name'].value_counts(dropna = True)   #印出該欄位內資料的累加，刪除NAN值
# Out:
# 1898 Mountain Rd NW, Albuquerque, NM 87104, USA     802
# Central @ Tingley, Albuquerque, NM 87104, USA       622
# 330 Tijeras Ave NW, Albuquerque, NM 87102, USA      529
# 2550 Central Ave NE, Albuquerque, NM 87106, USA     478
# 201 Marquette Ave NW, Albuquerque, NM 87102, USA    387
#                                                    ...
# 407 Harvard Dr SE, Albuquerque, NM 87106, USA         1
# 526 Wellesley Dr SE, Albuquerque, NM 87106, USA       1
# 2315 Lead Ave SE, Albuquerque, NM 87106, USA          1
# 509 Iron Ave SW, Albuquerque, NM 87102, USA           1
# 1417 Lomas Blvd NW, Albuquerque, NM 87104, USA        1
# Name: end_location_name, Length: 4263, dtype: int64

# %%
df.isnull().sum()      #將各個欄位內的缺失值累加起來
# Out:
# month                     0
# trip_id                   0
# region_id                 0
# vehicle_id                0
# started_at                0
# ended_at                  0
# DURATION               2308
# start_location_name       6
# end_location_name      2070
# user_id                   0
# trip_ledger_id            0
# dtype: int64

# %%
df['trip_id'].value_counts()           #將該欄位所有重複的資料做累加
# Out:
# 1835008    1
# 1961292    1
# 2159021    1
# 2093547    1
# 2481246    1
#           ..
# 1649743    1
# 1719373    1
# 1903691    1
# 1907785    1
# 2361343    1
# Name: trip_id, Length: 34226, dtype: int64

# %%
df['trip_id'].value_counts(bins=10)        #將該欄位所有重複的資料做累加，並將資料用區間方式合併，分成10個部分
# Out:
# (1787135.0, 1874035.0]      5561
# (1700235.0, 1787135.0]      4900
# (1874035.0, 1960935.0]      4316
# (1960935.0, 2047835.0]      3922
# (2047835.0, 2134735.0]      3296
# (2221635.0, 2308535.0]      2876
# (2308535.0, 2395435.0]      2515
# (2134735.0, 2221635.0]      2490
# (2395435.0, 2482335.0]      2228
# (1612465.999, 1700235.0]    2122
# Name: trip_id, dtype: int64
